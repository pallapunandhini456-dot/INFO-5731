# %% [markdown]
# <a href="https://colab.research.google.com/github/pallapunandhini456-dot/INFO-5731/blob/main/in_class_exercise_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My first Python code for NLP
# Name: Nandini
# Course: INFO 5731

# %%
print("Hello, Google Colab")
# Out:
# Hello, Google Colab

# %%
a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
subjects = ["IR", "NLP", "Data", "Python"]
print(subjects)
# Out:
# ['IR', 'NLP', 'Data', 'Python']

# %%
for s in subjects:
    print(s)
# Out:
# IR
# NLP
# Data
# Python

# %% [markdown]
# This exercise helped me understand how to use Google Colab,
# add text and code cells, and run basic Python programs.
